# %% [markdown]
# <a href="https://colab.research.google.com/github/shivpandey2406/python_AIML/blob/main/Googleplaystore_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/shivpandey2406/python_AIML
# Out:
# fatal: destination path 'python_AIML' already exists and is not an empty directory.

# %% [markdown]
# # Import the required library

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
data = pd.read_csv('/content/python_AIML/googleplaystore.csv')

# %% [markdown]
# #1. Display Top 5 Rows of The Dataset

# %%
data.head(1573)
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 1568                           Chart - Myanmar Keyboard       LIFESTYLE
# 1569                              Easy Makeup Tutorials       LIFESTYLE
# 1570  Horoscopes – Daily Zodiac Horoscope and Astrology       LIFESTYLE
# 1571                                              Entel       LIFESTYLE
# 1572                                    ZenUI Safeguard       LIFESTYLE
#
#       Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# #2. Check the Last 3 Rows of The Dataset

# %%
data.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %% [markdown]
# #3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
data.shape
print('Number of Rows',data.shape[0])
print('Number of Columns',data.shape[1])
# Out:
# Number of Rows 10841
# Number of Columns 13

# %% [markdown]
# #4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column and Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #5. Get Overall Statistics About the Dataframe.

# %%
data.describe(include= 'all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# #6. Total Number of App Titles Contain Astrology

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#data['App'].str.contains('Astrology') # This is an case sensitive

# %%
# And for case Insensitive  and find the total count
len(data[data['App'].str.contains('Astrology',case = False)])
# Out:
# 3

# %% [markdown]
# #7. Find Average App Rating

# %%
data.columns
data['Rating'].mean()
# Out:
# 4.193338315362443

# %% [markdown]
# #8. Find Total Number of Unique Category

# %%
data['Category'].nunique()
# Out:
# 34

# %% [markdown]
# # 9. Which Category Getting the Highest Average Rating?

# %%
data.groupby('Category')['Rating'].mean().sort_values(ascending = False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %% [markdown]
# #10. Find Total Number of App having 5 Star Rating

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
len(data[data['Rating'] == 5])
# Out:
# 274

# %% [markdown]
# #11. Find Average Value of Reviews

# %%
data['Reviews'].dtypes
# Out:
# dtype('O')

# %%
data[data['Reviews']== '3.0M']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
data['Reviews'] = data['Reviews'].replace('3.0M',3.0 )

# %%
data['Reviews'] = data['Reviews'].astype('float')

# %%
data['Reviews'].dtypes
# Out:
# dtype('float64')

# %%
data['Reviews'].mean()
# Out:
# 444111.9265750392

# %% [markdown]
# #12. Find Total Number of Free and Paid Apps

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %% [markdown]
# #13. Which App Has Maximum Reviews?

# %%
data.head()
data['App'][data['Reviews'].idxmax()]
# Out:
# 'Facebook'

# %% [markdown]
# # Alternate Solutions

# %%
data[data['Reviews'].max() == data['Reviews']]['App']
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %% [markdown]
# #14. Display Top 5 Apps Having Highest Reviews

# %%
data.sort_values(by = 'Reviews', ascending=False).head()
# Out:
#                      App       Category  Rating     Reviews  \
# 2544            Facebook         SOCIAL     4.1  78158306.0
# 3943            Facebook         SOCIAL     4.1  78128208.0
# 381   WhatsApp Messenger  COMMUNICATION     4.4  69119316.0
# 336   WhatsApp Messenger  COMMUNICATION     4.4  69119316.0
# 3904  WhatsApp Messenger  COMMUNICATION     4.4  69109672.0
#
#                     Size        Installs  Type Price Content Rating  \
# 2544  Varies with device  1,000,000,000+  Free     0           Teen
# 3943  Varies with device  1,000,000,000+  Free     0           Teen
# 381   Varies with device  1,000,000,000+  Free     0       Everyone
# 336   Varies with device  1,000,000,000+  Free     0       Everyone
# 3904  Varies with device  1,000,000,000+  Free     0       Everyone
#
#              Genres    Last Updated         Current Ver         Android Ver
# 2544         Social  August 3, 2018  Varies with device  Varies with device
# ...

# %% [markdown]
# #15. Find Average Rating of Free and Paid Apps

# %%
data.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# # 16. Display Top 5 Apps Having Maximum Installs

# %%
data.sort_values(by = 'Installs', ascending = False ).head()
# Out:
#                                                App            Category  \
# 10472      Life Made WI-Fi Touchscreen Photo Frame                 1.9
# 420    UC Browser - Fast Download Private & Secure       COMMUNICATION
# 474                    LINE: Free Calls & Messages       COMMUNICATION
# 3767                  Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 3574                                   Cloud Print        PRODUCTIVITY
#
#        Rating     Reviews                Size      Installs  Type     Price  \
# 10472    19.0         3.0              1,000+          Free     0  Everyone
# 420       4.5  17714850.0                 40M  500,000,000+  Free         0
# 474       4.2  10790289.0  Varies with device  500,000,000+  Free         0
# 3767      4.4   1284017.0  Varies with device  500,000,000+  Free         0
# 3574      4.1    282460.0  Varies with device  500,000,000+  Free         0
#
#       Content Rating             Genres    Last Updated         Current Ver  \
# ...
